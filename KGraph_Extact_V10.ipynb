# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

# %%
# packages used by helper functions
import uuid

# %%
# packages for prompting definitions
import sys
sys.path.append("..")
import json

# %%
from langchain_community.llms import Ollama

# %%
import ollama
from ollama import Client
client = Client(host='http://localhost:11434')

# %% [markdown]
# ## Prompt definitions (function to extract triplets in JSON-format for knowledge graph from text chunks)

# %%
#################################
# Definition of used LLM
#################################
##########################################################################
def graphPrompt(input: str, metadata={}, model="mixtral:latest"):
    if model == None:
        model = "mixtral:latest"
    
    chunk_id = metadata.get('chunk_id', None)

    # model_info = client.show(model_name=model)
    # print( chalk.blue(model_info))

    SYS_PROMPT = ("You are a network graph maker who extracts terms and their relations from a given context. "
        "You are provided with a context chunk (delimited by ```) Your task is to extract the ontology "
        "of terms mentioned in the given context. These terms should represent the key concepts as per the context. \n"
        "Thought 1: While traversing through each sentence, Think about the key terms mentioned in it.\n"
            "\tTerms may include person (agent), location, organization, date, duration, \n"
            "\tcondition, concept, object, entity  etc.\n"
            "\tTerms should be as atomistic as possible\n\n"
        "Thought 2: Think about how these terms can have one on one relation with other terms.\n"
            "\tTerms that are mentioned in the same sentence or the same paragraph are typically related to each other.\n"
            "\tTerms can be related to many other terms\n\n"
        "Thought 3: Find out the relation between each such related pair of terms. \n\n"
        "Format your output as a list of json. Each element of the list contains a pair of terms"
        "and the relation between them like the follwing. NEVER change the value of the chunk_ID as defined in this prompt: \n"
        "[\n"
        "   {\n"
        '       "chunk_id": "CHUNK_ID_GOES_HERE",\n'
        '       "node_1": "A concept from extracted ontology",\n'
        '       "node_2": "A related concept from extracted ontology",\n'
        '       "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"\n' 
        "   }, {...}\n"
        "]"
    )
    SYS_PROMPT = SYS_PROMPT.replace('CHUNK_ID_GOES_HERE', chunk_id)

    USER_PROMPT = f"context: ```{input}``` \n\n output: "

    response = client.generate(model="mixtral:latest", system=SYS_PROMPT, prompt=USER_PROMPT)

    aux1 = response['response']
    # Find the index of the first open bracket '['
    start_index = aux1.find('[')
    # Slice the string from start_index to extract the JSON part and fix an unexpected problem with insertes escapes (WHY ?)
    json_string = aux1[start_index:]
    json_string = json_string.replace('\\\\\_', '_')
    json_string = json_string.replace('\\\\_', '_')
    json_string = json_string.replace('\\\_', '_')
    json_string = json_string.replace('\\_', '_')
    json_string = json_string.replace('\_', '_')
    json_string.lstrip() # eliminate eventual leading blank spaces
#####################################################
    print("json-string:\n" + json_string)
#####################################################         
    try:
        result = json.loads(json_string)
        result = [dict(item) for item in result]
    except:
        print("\n\nERROR ### Here is the buggy response: ", response, "\n\n")
        result = None
    print("§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§")

    return result

# %% [markdown]
# ## Functions

# %%
def documents2Dataframe(documents) -> pd.DataFrame:
    rows = []
    for chunk in documents:
        row = {
            "text": chunk.page_content,
            **chunk.metadata,
            "chunk_id": uuid.uuid4().hex,
        }
        rows = rows + [row]

    df = pd.DataFrame(rows)
    return df

# %%
def df2Graph(dataframe: pd.DataFrame, model=None) -> list:
    # dataframe.reset_index(inplace=True)
    results = dataframe.apply(
        lambda row: graphPrompt(row.text, {"chunk_id": row.chunk_id}, model), axis=1
    )
    # invalid json results in NaN
    results = results.dropna()
    results = results.reset_index(drop=True)

    ## Flatten the list of lists to one single list of entities.
    concept_list = np.concatenate(results).ravel().tolist()
    return concept_list

# %%
def graph2Df(nodes_list) -> pd.DataFrame:
    ## Remove all NaN entities
    graph_dataframe = pd.DataFrame(nodes_list).replace(" ", np.nan)
    graph_dataframe = graph_dataframe.dropna(subset=["node_1", "node_2"])
    graph_dataframe["node_1"] = graph_dataframe["node_1"].apply(lambda x: x.lower())
    graph_dataframe["node_2"] = graph_dataframe["node_2"].apply(lambda x: x.lower())

    return graph_dataframe

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2

# %% [markdown]
# ## Variables

# %%
## Input data directory
##########################################################
input_file_name = "Saxony_Eastern_Expansion_EP_96.txt"
input_file_name = "Harry_Potter_1_chapter_1.txt"
##########################################################
data_dir = "HotG_Data/"+input_file_name
inputdirectory = Path(f"./{data_dir}")

## This is where the output csv files will be written
outputdirectory = Path(f"./data_output")

# %%
output_graph_file_name = f"graph_{input_file_name[:-4]}.csv"
output_graph_file_with_path = outputdirectory/output_graph_file_name

output_chunks_file_name = f"chunks_{input_file_name[:-4]}.csv"
output_chunks_file_with_path = outputdirectory/output_chunks_file_name

output_context_prox_file_name = f"graph_contex_prox_{input_file_name[:-4]}.csv"
output_context_prox_file_with_path = outputdirectory/output_context_prox_file_name

print(output_graph_file_with_path)
print(output_chunks_file_with_path)
print(output_context_prox_file_with_path)
# Out:
# data_output/graph_Harry_Potter_1_chapter_1.csv
# data_output/chunks_Harry_Potter_1_chapter_1.csv
# data_output/graph_contex_prox_Harry_Potter_1_chapter_1.csv

# %% [markdown]
# ## Load Documents

# %%
#loader = TextLoader("./HotG_Data/Hanse.txt")
loader = TextLoader(inputdirectory)
Document = loader.load()
# clean unnecessary line breaks
Document[0].page_content = Document[0].page_content.replace("\n", " ")

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(Document)
print("Number of chunks = ", len(pages))
print(pages[5].page_content)
# Out:
# Number of chunks =  29
# owl-free morning. He yelled at five different people. He made several important telephone calls and shouted a bit more. He was in a very good mood until lunchtime, when he thought he'd stretch his legs and walk across the road to buy himself a bun from the bakery. He'd forgotten all about the people in cloaks until he passed a group of them next to the baker's. He eyed them angrily as he passed. He didn't know why, but they made him uneasy. This bunch were whispering excitedly, too, and he couldn't see a single collecting tin. It was on his way back past them, clutching a large doughnut in a bag, that he caught a few words of what they were saying. "The Potters, that's right, that's what I heard yes, their son, Harry" Mr. Dursley stopped dead. Fear flooded him. He looked back at the whisperers as if he wanted to say something to them, but thought better of it. He dashed back across the road, hurried up to his office, snapped at his secretary not to disturb him, seized his telephone,

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (29, 3)
#                                                 text  \
# 0  Mr. and Mrs. Dursley, of number four, Privet D...
# 1  found out about the Potters. Mrs. Potter was M...
# 2  wrestled a screaming Dudley into his high chai...
# 3  Mr. Dursley drove around the corner and up the...
# 4  excitedly together. Mr. Dursley was enraged to...
#
#                                    source                          chunk_id
# 0  HotG_Data/Harry_Potter_1_chapter_1.txt  55fba9390d9b40a9b2080b407539097c
# 1  HotG_Data/Harry_Potter_1_chapter_1.txt  48e4a5ce2c81495db5523f7dcbc077d6
# 2  HotG_Data/Harry_Potter_1_chapter_1.txt  301738c0377846e784ed8b1b3c46a026
# 3  HotG_Data/Harry_Potter_1_chapter_1.txt  5201307e46a34a59b226337712056aac
# 4  HotG_Data/Harry_Potter_1_chapter_1.txt  4bf0d253006d4bb79aea3ded8b287a68

# %% [markdown]
# ## Extract Concepts

# %%
## To regenerate the graph with LLM, set this to True
##################
regenerate = False  # toggle to True if the time-consuming (re-)generation of the knowlege extraction is required
regenerate = True
##################
if regenerate:
#########################################################    
    concepts_list = df2Graph(df, model='mixtral:latest')
#########################################################
    dfg1 = graph2Df(concepts_list)
    
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(output_graph_file_with_path, sep=";", index=False)
    df.to_csv(output_chunks_file_with_path, sep=";", index=False)
else:
    dfg1 = pd.read_csv(output_graph_file_with_path, sep=";")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# json-string:
# [
#    {
#        "chunk_id": "55fba9390d9b40a9b2080b407539097c",
#        "node_1": "Mr. Dursley",
#        "node_2": "Grunnings",
#        "edge": "Mr. Dursley is the director of Grunnings, a firm that makes drills."
#    },
#    {
#        "chunk_id": "55fba9390d9b40a9b2080b407539097c",
#        "node_1": "Dudley",
#        "node_2": "The Dursleys",
#        "edge": "Dudley is the small son of the Dursleys."
#    },
#    {
#        "chunk_id": "55fba9390d9b40a9b2080b407539097c",
#        "node_1": "The Dursleys",
#        "node_2": "secret",
#        "edge": "The Dursleys have a secret, and their greatest fear is that somebody would discover it."
#    },
#    {
#        "chunk_id": "55fba9390d9b40a9b2080b407539097c",
#        "node_1": "The Dursleys",
#        "node_2": "Mrs. Potter's family",
#        "edge": "The Dursleys' greatest fear is that someone would find out about the Potters."
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "48e4a5ce2c81495db5523f7dcbc077d6",
#        "node_1": "Mr. Dursley",
#        "node_2": "Mrs. Dursley's sister's husband",
#        "edge": "Mr. Dursley considers Mrs. Dursley's sister's husband as a good-for-nothing person"
#    },
#    {
#        "chunk_id": "48e4a5ce2c81495db5523f7dcbc077d6",
#        "node_1": "The Dursleys",
#        "node_2": "The Potters",
#        "edge": "The Dursleys want to keep the Potters away due to their unDursleyish nature and the possibility of their son's bad influence on Dudley"
#    },
#    {
#        "chunk_id": "48e4a5ce2c81495db5523f7dcbc077d6",
#        "node_1": "The Potters' son",
#        "node_2": "Dudley",
#        "edge": "The Potters' son and Dudley have never met"
#    },
#    {
#        "chunk_id": "48e4a5ce2c81495db5523f7dcbc077d6",
#        "node_1": "The weather",
#        "node_2": "Strange and mysterious things happening all over the country",
#        "edge": "There is no connection between the dull, gray weather and the strange and mysterious things happening all over the country"
#    },
#    {
#        "chunk_id": "48e4a5ce2c81495db5523f7dcbc077d6",
#        "node_1": "Large, tawny owl",
#        "node_2": "The events happening all over the country",
#        "edge": "The large, tawny owl's appearance is a sign of the strange and mysterious things happening all over the country"
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "301738c0377846e784ed8b1b3c46a026",
#        "node_1": "Mr. Dursley",
#        "node_2": "half past eight",
#        "edge": "Mr. Dursley picked up his briefcase and left the house at half past eight"
#    },
#    {
#        "chunk_id": "301738c0377846e784ed8b1b3c46a026",
#        "node_1": "Mr. Dursley",
#        "node_2": "car",
#        "edge": "Mr. Dursley got into his car and backed out of number four's drive"
#    },
#    {
#        "chunk_id": "301738c0377846e784ed8b1b3c46a026",
#        "node_1": "cat",
#        "node_2": "map",
#        "edge": "Mr. Dursley initially thought he saw a cat reading a map"
#    },
#    {
#        "chunk_id": "301738c0377846e784ed8b1b3c46a026",
#        "node_1": "cat",
#        "node_2": "Mr. Dursley",
#        "edge": "The cat stared back at Mr. Dursley as he drove away"
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "5201307e46a34a59b226337712056aac",
# "node_1": "Mr. Dursley",
# "node_2": "driving",
# "edge": "Mr. Dursley is engaged in the action of driving a vehicle"
# },
# {
# "chunk_id": "5201307e46a34a59b226337712056aac",
# "node_1": "Mr. Dursley",
# "node_2": "looking at the sign",
# "edge": "Mr. Dursley is looking at a sign"
# },
# {
# "chunk_id": "5201307e46a34a59b226337712056aac",
# "node_1": "cat",
# "node_2": "looking at the sign",
# "edge": "The cat is also looking at the sign, though cats can't read maps or signs"
# },
# {
# "chunk_id": "5201307e46a34a59b226337712056aac",
# "node_1": "Mr. Dursley",
# "node_2": "thinking of large order of drills",
# "edge": "Mr. Dursley is thinking about a large order of drills he hopes to get that day"
# },
# {
# "chunk_id": "5201307e46a34a59b226337712056aac",
# "node_1": "Mr. Dursley",
# "node_2": "noticing strange people",
# "edge": "Mr. Dursley notices a lot of strangely dressed people about in the morning traffic jam"
# },
# {
# "chunk_id": "5201307e46a34a59b226337712056aac",
# "node_1": "strangely dressed people",
# "node_2": "whispering excitedly together",
# "edge": "The strangely dressed people are whispering excitedly together"
# },
# {
# "chunk_id": "5201307e46a34a59b226337712056aac",
# "node_1": "strangely dressed people",
# "node_2": "not young",
# "edge": "A couple of the strangely dressed people aren't young at all"
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "4bf0d253006d4bb79aea3ded8b287a68",
# "node_1": "Mr. Dursley",
# "node_2": "Grunnings parking lot",
# "edge": "Mr. Dursley arrived in the Grunnings parking lot after leaving the street where owls were swooping past."
# },
# {
# "chunk_id": "4bf0d253006d4bb79aea3ded8b287a68",
# "node_1": "Mr. Dursley",
# "node_2": "owls",
# "edge": "Mr. Dursley did not see the owls swooping past in broad daylight from his office on the ninth floor."
# },
# {
# "chunk_id": "4bf0d253006d4bb79aea3ded8b287a68",
# "node_1": "people down in the street",
# "node_2": "owls",
# "edge": "People down in the street pointed and gazed open-mouthed as owl after owl sped overhead."
# },
# {
# "chunk_id": "4bf0d253006d4bb79aea3ded8b287a68",
# "node_1": "Mr. Dursley",
# "node_2": "five different people",
# "edge": "Mr. Dursley yelled at five different people."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "morning",
#        "node_2": "owl-free",
#        "edge": "describes the time of day, with no owls present"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "he",
#        "node_2": "five different people",
#        "edge": "addressed or communicated with"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "he",
#        "node_2": "several important telephone calls",
#        "edge": "made or received"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "he",
#        "node_2": "lunchtime",
#        "edge": "occurred or took place around this time"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "he",
#        "node_2": "bakery",
#        "edge": "visited or intended to visit"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "people in cloaks",
#        "node_2": "whispering excitedly",
#        "edge": "engaged in this behavior"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "people in cloaks",
#        "node_2": "collecting tin",
#        "edge": "associated with or expected to have this item"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "Mr. Dursley",
#        "node_2": "people in cloaks",
#        "edge": "noticed or paid attention to"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "Mr. Dursley",
#        "node_2": "The Potters, that's right, that's what I heard yes, their son, Harry",
#        "edge": "overheard or learned about"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "The Potters",
#        "node_2": "son, Harry",
#        "edge": "has a child by this name"
#    },
#    {
#        "chunk_id": "2f27a545789d4b66a01c45b6b84c1bb6",
#        "node_1": "Mr. Dursley",
#        "node_2": "fear",
#        "edge": "experienced this emotion"
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
# "chunk_id": "d7eace97027c48ffa66d081e8995de2b",
# "node_1": "secretary",
# "node_2": "office",
# "edge": "The secretary is associated with the office as it is her workplace where she was snapped at by her boss."
# },
# {
# "chunk_id": "d7eace97027c48ffa66d081e8995de2b",
# "node_1": "secretary",
# "node_2": "boss",
# "edge": "The secretary is associated with her boss as he is the one who snapped at her."
# },
# {
# "chunk_id": "d7eace97027c48ffa66d081e8995de2b",
# "node_1": "man",
# "node_2": "home number",
# "edge": "The man is associated with the home number as he was about to dial it before changing his mind."
# },
# {
# "chunk_id": "d7eace97027c48ffa66d081e8995de2b",
# "node_1": "man",
# "node_2": "nephew",
# "edge": "The man is associated with his nephew as he was initially worried about him but then changed his mind."
# },
# {
# "chunk_id": "d7eace97027c48ffa66d081e8995de2b",
# "node_1": "man",
# "node_2": "Mrs. Dursley",
# "edge": "The man is associated with Mrs. Dursley as he doesn't want to upset her by mentioning her sister."
# },
# {
# "chunk_id": "d7eace97027c48ffa66d081e8995de2b",
# "node_1": "man",
# "node_2": "people in cloaks",
# "edge": "The man is associated with the people in cloaks as he finds it hard to concentrate on drills because of them."
# },
# {
# "chunk_id": "d7eace97027c48ffa66d081e8995de2b",
# "node_1": "man",
# "node_2": "tiny old man",
# "edge": "The man is associated with the tiny old man as he walked into him outside the building."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
#    "chunk_id": "7873dc4519f8461f8b8d6fcf0737142e",
#    "node_1": "Mr. Dursley",
#    "node_2": "stranger",
#    "edge": "Mr. Dursley, the main character, was hugged by a stranger in the context."
# },
# {
#    "chunk_id": "7873dc4519f8461f8b8d6fcf0737142e",
#    "node_1": "stranger",
#    "node_2": "violet cloak",
#    "edge": "The stranger was wearing a violet cloak."
# },
# {
#    "chunk_id": "7873dc4519f8461f8b8d6fcf0737142e",
#    "node_1": "stranger",
#    "node_2": "Muggle",
#    "edge": "The stranger called Mr. Dursley a Muggle, which he had never been called before."
# },
# {
#    "chunk_id": "7873dc4519f8461f8b8d6fcf0737142e",
#    "node_1": "stranger",
#    "node_2": "happy",
#    "edge": "The stranger was happy and celebrating because You-Know-Who had gone at last."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "2171e130a9bd43c68c02188858261b85",
# "node_1": "Mr. Dursley",
# "node_2": "tabby cat",
# "edge": "Mr. Dursley, the main character of the context, sees a tabby cat in his garden, which is unusual for him."
# },
# {
# "chunk_id": "2171e130a9bd43c68c02188858261b85",
# "node_1": "tabby cat",
# "node_2": "Mr. Dursley's garden wall",
# "edge": "The tabby cat is sitting on Mr. Dursley's garden wall."
# },
# {
# "chunk_id": "2171e130a9bd43c68c02188858261b85",
# "node_1": "tabby cat",
# "node_2": "unusual behavior",
# "edge": "The tabby cat is displaying unusual behavior by not moving when Mr. Dursley tells it to."
# },
# {
# "chunk_id": "2171e130a9bd43c68c02188858261b85",
# "node_1": "Mr. Dursley",
# "node_2": "normal behavior",
# "edge": "Mr. Dursley is trying to act normally, despite the unusual occurrences."
# },
# {
# "chunk_id": "2171e130a9bd43c68c02188858261b85",
# "node_1": "Mrs. Dursley",
# "node_2": "normal day",
# "edge": "Mrs. Dursley had a normal day, in contrast to her husband's unusual experiences."
# },
# {
# "chunk_id": "2171e130a9bd43c68c02188858261b85",
# "node_1": "Mrs. Next Door",
# "node_2": "daughter's problems",
# "edge": "Mrs. Dursley discussed Mrs. Next Door's problems with her daughter."
# },
# {
# "chunk_id": "2171e130a9bd43c68c02188858261b85",
# "node_1": "Dudley",
# "node_2": "learning new word",
# "edge": "Mrs. Dursley told Mr. Dursley that Dudley had learned a new word, 'Won't!'"
# },
# {
# "chunk_id": "2171e130a9bd43c68c02188858261b85",
# "node_1": "nation's owls",
# "node_2": "unusual behavior",
# "edge": "The nation's owls are behaving unusually, as reported by bird-watchers."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
#     "chunk_id": "91d8ed7b6f43469fbf8c365937777dce",
#     "node_1": "nation's owls",
#     "node_2": "unusual behavior",
#     "edge": "The nation's owls have been exhibiting behavior that is not typical for them, such as flying in every direction during the daytime."
# },
# {
#     "chunk_id": "91d8ed7b6f43469fbf8c365937777dce",
#     "node_1": "owls",
#     "node_2": "night hunting",
#     "edge": "Owls typically hunt at night and are hardly ever seen in daylight."
# },
# {
#     "chunk_id": "91d8ed7b6f43469fbf8c365937777dce",
#     "node_1": "experts",
#     "node_2": "unable to explain",
#     "edge": "Experts are currently unable to provide an explanation for the change in the owls' sleeping pattern."
# },
# {
#     "chunk_id": "91d8ed7b6f43469fbf8c365937777dce",
#     "node_1": "viewers",
#     "node_2": "downpour of shooting stars",
#     "edge": "Viewers in various parts of Britain have reported seeing a large number of shooting stars."
# },
# {
#     "chunk_id": "91d8ed7b6f43469fbf8c365937777dce",
#     "node_1": "weatherman",
#     "node_2": "promise of rain",
#     "edge": "The weatherman had previously promised that there would be rain, but it did not occur."
# },
# {
#     "chunk_id": "91d8ed7b6f43469fbf8c365937777dce",
#     "node_1": "Mr. Dursley",
#     "node_2": "frozen in armchair",
#     "edge": "Mr. Dursley was so surprised by the news that he remained seated and motionless in his armchair."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "5e6a39886ae44e48ade45448fc9051ca",
#        "node_1": "Mr. Dursley",
#        "node_2": "Petunia",
#        "edge": "Mr. Dursley is Petunia's husband"
#    },
#    {
#        "chunk_id": "5e6a39886ae44e48ade45448fc9051ca",
#        "node_1": "Petunia",
#        "node_2": "Mrs. Dursley",
#        "edge": "Petunia is referred to as Mrs. Dursley"
#    },
#    {
#        "chunk_id": "5e6a39886ae44e48ade45448fc9051ca",
#        "node_1": "Mrs. Dursley",
#        "node_2": "sister of Petunia",
#        "edge": "Mrs. Dursley is the sister of Petunia"
#    },
#    {
#        "chunk_id": "5e6a39886ae44e48ade45448fc9051ca",
#        "node_1": "sister of Petunia",
#        "node_2": "Lily Potter (implied)",
#        "edge": "The sister of Petunia is Lily Potter"
#    },
#    {
#        "chunk_id": "5e6a39886ae44e48ade45448fc9051ca",
#        "node_1": "Mr. Dursley",
#        "node_2": "heard the name 'Potter'",
#        "edge": "Mr. Dursley has heard the name 'Potter'"
#    },
#    {
#        "chunk_id": "5e6a39886ae44e48ade45448fc9051ca",
#        "node_1": "'Potter'",
#        "node_2": "sister of Petunia",
#        "edge": "The name 'Potter' is related to Petunia's sister"
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "de8390d2666c4b31ab146f95461b7042",
# "node_1": "Mr. Dursley",
# "node_2": "Dudley's age",
# "edge": "Mr. Dursley is related to Dudley in terms of being his father, and he is comparing the age of Dudley with that of 'their son'"
# },
# {
# "chunk_id": "de8390d2666c4b31ab146f95461b7042",
# "node_1": "Mrs. Dursley",
# "node_2": "their son",
# "edge": "Mrs. Dursley is the mother of 'their son', as indicated by her response to Mr. Dursley's question about his age."
# },
# {
# "chunk_id": "de8390d2666c4b31ab146f95461b7042",
# "node_1": "their son",
# "node_2": "Howard/Harry",
# "edge": "The son of the Dursleys is named Harry, but Mr. Dursley mistakenly refers to him as Howard, indicating a possible disconnect or lack of familiarity with 'their son'."
# },
# {
# "chunk_id": "de8390d2666c4b31ab146f95461b7042",
# "node_1": "Harry",
# "node_2": "nasty, common name",
# "edge": "Mr. Dursley expresses a negative opinion about the name Harry, suggesting a potential issue with their son's name."
# },
# {
# "chunk_id": "de8390d2666c4b31ab146f95461b7042",
# "node_1": "Harry",
# "node_2": "Potters",
# "edge": "The surname of the Dursleys' son is Potter, and Mr. Dursley wonders if there is a connection between the Potters and the cat's behavior in the garden."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "3af2f8a6fc7647bb8261baaf83a
#
#
# ERROR ### Here is the buggy response:  {'model': 'mixtral:latest', 'created_at': '2024-05-14T15:50:11.767725Z', 'response': ' [\n {\n"chunk_id": "3af2f8a6fc7647bb8261baaf83a', 'done': True, 'done_reason': 'stop', 'context': [28705, 733, 16289, 28793, 995, 460, 264, 3681, 5246, 27065, 693, 9131, 28713, 3471, 304, 652, 3136, 477, 264, 2078, 2758, 28723, 995, 460, 3857, 395, 264, 2758, 11077, 325, 5149, 321, 1345, 486, 8789, 28731, 3604, 3638, 349, 298, 9131, 272, 7957, 2161, 302, 3471, 7083, 297, 272, 2078, 2758, 28723, 2957, 3471, 1023, 2904, 272, 1945, 16582, 390, 660, 272, 2758, 28723, 28705, 13, 1227, 1322, 28705, 28740, 28747, 4023, 19483, 288, 1059, 1430, 12271, 28725, 15403, 684, 272, 1945, 3471, 7083, 297, 378, 28723, 13, 12, 11579, 28713, 993, 3024, 1338, 325, 14702, 557, 4723, 28725, 6666, 28725, 3608, 28725, 11964, 28725, 28705, 13, 12, 12058, 28725, 5935, 28725, 1928, 28725, 9040, 28705, 4345, 28723, 13, 12, 11579, 28713, 1023, 347, 390, 18040, 3320, 390, 2572, 13, 13, 1227, 1322, 28705, 28750, 28747, 15403, 684, 910, 1167, 3471, 541, 506, 624, 356, 624, 9378, 395, 799, 3471, 28723, 13, 12, 11579, 28713, 369, 460, 7083, 297, 272, 1348, 12271, 442, 272, 1348, 18438, 460, 9566, 5202, 298, 1430, 799, 28723, 13, 12, 11579, 28713, 541, 347, 5202, 298, 1287, 799, 3471, 13, 13, 1227, 1322, 28705, 28770, 28747, 8769, 575, 272, 9378, 1444, 1430, 1259, 5202, 5964, 302, 3471, 28723, 28705, 13, 13, 5056, 574, 3825, 390, 264, 1274, 302, 7611, 28723, 7066, 2442, 302, 272, 1274, 5876, 264, 5964, 302, 3471, 391, 272, 9378, 1444, 706, 737, 272, 285, 793, 9988, 28723, 9991, 3491, 2268, 272, 1192, 302, 272, 11077, 28730, 1138, 390, 4057, 297, 456, 11510, 28747, 28705, 13, 28792, 13, 259, 371, 13, 428, 345, 13567, 28730, 313, 1264, 345, 28770, 2015, 28750, 28722, 28783, 28708, 28784, 6837, 28787, 28784, 28781, 28787, 1754, 28783, 28750, 28784, 28740, 3175, 2015, 28783, 28770, 28708, 28750, 28740, 28784, 28787, 28726, 548, 13, 428, 345, 2315, 28730, 28740, 1264, 345, 28741, 5935, 477, 25081, 7957, 2161, 548, 13, 428, 345, 2315, 28730, 28750, 1264, 345, 28741, 5202, 5935, 477, 25081, 7957, 2161, 548, 13, 428, 345, 8424, 1264, 345, 3045, 18798, 1444, 272, 989, 16582, 28725, 3179, 28730, 28740, 304, 3179, 28730, 28750, 297, 624, 442, 989, 23748, 28739, 13, 259, 1630, 371, 1101, 28752, 13, 28793, 2758, 28747, 8789, 9635, 2855, 28723, 7107, 28723, 384, 1726, 2047, 5970, 15231, 4377, 562, 2964, 28723, 384, 1726, 2047, 4897, 20875, 28725, 8528, 378, 544, 754, 297, 516, 2273, 28723, 2354, 1432, 28725, 5034, 288, 1654, 1159, 400, 5970, 15231, 403, 369, 1019, 513, 272, 10650, 1532, 654, 5290, 28725, 736, 403, 708, 2611, 354, 706, 298, 1567, 3065, 713, 304, 7107, 28723, 384, 1726, 2047, 28723, 415, 10650, 1532, 2580, 1215, 1162, 767, 400, 304, 6728, 370, 515, 1654, 684, 706, 304, 652, 2112, 3406, 650, 3481, 28742, 28707, 1032, 910, 400, 304, 6728, 370, 515, 829, 625, 9430, 582, 297, 2424, 369, 1659, 347, 1404, 356, 1939, 400, 10129, 880, 286, 304, 2897, 754, 1939, 378, 3481, 28742, 28707, 5197, 706, 3406, 1602, 1215, 3544, 400, 403, 28723, 2964, 28723, 384, 1726, 2047, 1659, 506, 750, 1605, 13120, 778, 396, 2219, 5826, 4289, 28725, 562, 272, 5255, 356, 272, 3500, 3536, 403, 8102, 708, 1492, 302, 4289, 1494, 28723, 661, 403, 6398, 390, 1309, 390, 264, 22594, 28725, 871, 2282, 6321, 521, 1231, 655, 7381, 356, 272, 2082, 6581, 302, 15650, 299, 16857, 28723, 661, 1539, 28742, 28707, 579, 1188, 390, 526, 2023, 739, 264, 1253, 2251, 27165, 356, 272, 1679, 5948, 28725, 4678, 739, 989, 289, 28727, 4911, 20153, 11416, 20679, 28723, 560, 1639, 28725, 378, 403, 5597, 22494, 1159, 272, 5255, 4142, 438, 544, 28723, 330, 676, 6178, 356, 272, 6581, 272, 5255, 553, 750, 6265, 28725, 6178, 579, 6914, 304, 13940, 28832, 28705, 13, 13, 3825, 28747, 28705, 733, 28748, 16289, 28793, 733, 13, 371, 13, 28739, 13567, 28730, 313, 1264, 345, 28770, 2015, 28750, 28722, 28783, 28708, 28784, 6837, 28787, 28784, 28781, 28787, 1754, 28783, 28750, 28784, 28740, 3175, 2015, 28783, ...
#
#
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "cat",
# "node_2": "Privet Drive",
# "edge": "The cat is present at Privet Drive"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "man",
# "node_2": "corner",
# "edge": "The man appeared on the corner where the cat had been watching"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "man",
# "node_2": "Albus Dumbledore",
# "edge": "The man is referred to as Albus Dumbledore later in the context"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "Albus Dumbledore",
# "node_2": "tall, thin and very old",
# "edge": "The context describes Albus Dumbledore as tall, thin, and very old"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "Albus Dumbledore",
# "node_2": "silver hair and beard",
# "edge": "The context describes Albus Dumbledore's hair and beard as silver"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "Albus Dumbledore",
# "node_2": "long robes, purple cloak and high-heeled boots",
# "edge": "The context describes Albus Dumbledore's attire as long robes, a purple cloak and high-heeled boots"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "Albus Dumbledore",
# "node_2": "blue eyes, light, bright and sparkling behind half-moon spectacles",
# "edge": "The context describes Albus Dumbledore's eyes as blue, light, bright and sparkling behind half-moon spectacles"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "Albus Dumbledore",
# "node_2": "long and crooked nose",
# "edge": "The context describes Albus Dumbledore's nose as long and crooked"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "Albus Dumbledore",
# "node_2": "not realizing he had just arrived in a street where everything from his name to his boots was unwelcome",
# "edge": "The context states that Albus Dumbledore did not seem to realize he had just arrived in a street where everything from his name to his boots was unwelcome"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "Albus Dumbledore",
# "node_2": "rummaging in his cloak, looking for something",
# "edge": "The context states that Albus Dumbledore was rummaging in his cloak and looking for something"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "Albus Dumbledore",
# "node_2": "realizing he was being watched",
# "edge": "The context states that Albus Dumbledore realized he was being watched"
# },
# {
# "chunk_id": "8851b56c021a4ef699f2778ff2b00d8a",
# "node_1": "Albus Dumbledore",
# "node_2": "looking up suddenly at the cat",
# "edge": "The context states that Albus Dumbledore looked up suddenly at the cat"
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "7c0441bed2e246c5a064644b015d6502",
# "node_1": "Harry Potter",
# "node_2": "cat",
# "edge": "The cat was staring at Harry Potter, causing him to look up."
# },
# {
# "chunk_id": "7c0441bed2e246c5a064644b015d6502",
# "node_1": "Harry Potter",
# "node_2": "amusement",
# "edge": "The sight of the cat amused Harry Potter."
# },
# {
# "chunk_id": "7c0441bed2e246c5a064644b015d6502",
# "node_1": "Harry Potter",
# "node_2": "silver cigarette lighter",
# "edge": "Harry Potter found a silver cigarette lighter in his inside pocket."
# },
# {
# "chunk_id": "7c0441bed2e246c5a064644b015d6502",
# "node_1": "silver cigarette lighter",
# "node_2": "Put-Outer",
# "edge": "The silver cigarette lighter is also known as the Put-Outer."
# },
# {
# "chunk_id": "7c0441bed2e246c5a064644b015d6502",
# "node_1": "Put-Outer",
# "node_2": "street lamps",
# "edge": "The Put-Outer can be used to turn off street lamps."
# },
# {
# "chunk_id": "7c0441bed2e246c5a064644b015d6502",
# "node_1": "Put-Outer",
# "node_2": "darkness",
# "edge": "Clicking the Put-Outer results in darkness."
# },
# {
# "chunk_id": "7c0441bed2e246c5a064644b015d6502",
# "node_1": "Harry Potter",
# "node_2": "Dumbledore",
# "edge": "Dumbledore sat down next to Harry Potter."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "42d677c09af745d2aa2da7095a7609e3",
#        "node_1": "Harry Potter",
#        "node_2": "Professor McGonagall",
#        "edge": "Harry Potter identifies Professor McGonagall, who had been sitting as a cat, by noticing the way she sits."
#    },
#    {
#        "chunk_id": "42d677c09af745d2aa2da7095a7609e3",
#        "node_1": "Harry Potter",
#        "node_2": "tabby cat",
#        "edge": "Harry Potter mistakes the tabby cat for Professor McGonagall before she transforms back."
#    },
#    {
#        "chunk_id": "42d677c09af745d2aa2da7095a7609e3",
#        "node_1": "Professor McGonagall",
#        "node_2": "emerald cloak",
#        "edge": "Professor McGonagall is wearing an emerald cloak after transforming from a cat."
#    },
#    {
#        "chunk_id": "42d677c09af745d2aa2da7095a7609e3",
#        "node_1": "Professor McGonagall",
#        "node_2": "square glasses",
#        "edge": "Professor McGonagall wears square glasses that are the shape of the markings around the cat's eyes."
#    },
#    {
#        "chunk_id": "42d677c09af745d2aa2da7095a7609e3",
#        "node_1": "Professor McGonagall",
#        "node_2": "black hair in a tight bun",
#        "edge": "Professor McGonagall has black hair tied in a bun."
#    },
#    {
#        "chunk_id": "42d677c09af745d2aa2da7095a7609e3",
#        "node_1": "Professor McGonagall",
#        "node_2": "severe-looking woman",
#        "edge": "Harry Potter perceives Professor McGonagall as a severe-looking woman."
#    },
#    {
#        "chunk_id": "42d677c09af745d2aa2da7095a7609e3",
#        "node_1": "Professor McGonagall",
#        "node_2": "ruffled appearance",
#        "edge": "Professor McGonagall appears ruffled after sitting on a brick wall all day."
#    },
#    {
#        "chunk_id": "42d677c09af745d2aa2da7095a7609e3",
#        "node_1": "Professor McGonagall",
#        "node_2": "number of feasts and parties on her way here",
#        "edge": "Professor McGonagall passed by numerous celebrations while making her way to the meeting with Harry Potter."
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "b734649233ac4eb3bfdab773a79e65ac",
# "node_1": "Muggles",
# "node_2": "have noticed something's going on",
# "edge": "Muggles are aware of unusual events happening"
# },
# {
# "chunk_id": "b734649233ac4eb3bfdab773a79e65ac",
# "node_1": "unusual events",
# "node_2": "Flocks of owls, shooting stars",
# "edge": "Unusual events include flocks of owls and shooting stars"
# },
# {
# "chunk_id": "b734649233ac4eb3bfdab773a79e65ac",
# "node_1": "Flocks of owls, shooting stars",
# "node_2": "Muggles have noticed",
# "edge": "Muggles have observed unusual phenomena such as flocks of owls and shooting stars"
# },
# {
# "chunk_id": "b734649233ac4eb3bfdab773a79e65ac",
# "node_1": "Flocks of owls, shooting stars",
# "node_2": "Dedalus Diggle",
# "edge": "Dedalus Diggle is associated with the unusual events (likely the shooting stars)"
# },
# {
# "chunk_id": "b734649233ac4eb3bfdab773a79e65ac",
# "node_1": "Muggles",
# "node_2": "not completely stupid",
# "edge": "Muggles are not considered unintelligent for noticing unusual events"
# },
# {
# "chunk_id": "b734649233ac4eb3bfdab773a79e65ac",
# "node_1": "people",
# "node_2": "are being downright careless, out on the streets in broad daylight, not even dressed in Muggle clothes, swapping rumors",
# "edge": "People are behaving recklessly by being outside in broad daylight without Muggle clothing and spreading rumors"
# },
# {
# "chunk_id": "b734649233ac4eb3bfdab773a79e65ac",
# "node_1": "disappearance of YouKnow-Who",
# "node_2": "people are careless, spreading rumors",
# "edge": "People's carelessness and spread of rumors is associated with the disappearance of YouKnow-Who"
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
# "chunk_id": "0a172c4d70d34552bb20440b65f72350",
# "node_1": "YouKnow-Who",
# "node_2": "Voldemort",
# "edge": "In this context, they refer to the same person. Dumbledore is trying to persuade people to call him by his proper name, Voldemort, instead of using the euphemism 'YouKnow-Who'."
# },
# {
# "chunk_id": "0a172c4d70d34552bb20440b65f72350",
# "node_1": "Muggles",
# "node_2": "Non-magical people",
# "edge": "In this context, Muggles are referred to as non-magical people. Dumbledore and the others are worried about what might happen if Muggles find out about their existence."
# },
# {
# "chunk_id": "0a172c4d70d34552bb20440b65f72350",
# "node_1": "Lemon drops",
# "node_2": "A kind of Muggle sweet",
# "edge": "Dumbledore is fond of lemon drops, which are described as a kind of Muggle sweet. This suggests that there are cultural differences between the magical and non-magical worlds."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [   {
# "chunk_id": "17c96105c1404e8fa8440d826854b0dd",
# "node_1": "You-Know-Who",
# "node_2": "Voldemort",
# "edge": "You-Know-Who is a nickname or alias for the actual name Voldemort, as mentioned in the context."
# }, {
# "chunk_id": "17c96105c1404e8fa8440d826854b0dd",
# "node_1": "Voldemort",
# "node_2": "Dumbledore",
# "edge": "Both are mentioned as individuals having distinct powers, with a history of conflict."
# }, {
# "chunk_id": "17c96105c1404e8fa8440d826854b0dd",
# "node_1": "Dumbledore",
# "node_2": "Powers",
# "edge": "Dumbledore is mentioned to have certain powers that Voldemort has, but he refrains from using them."
# }, {
# "chunk_id": "17c96105c1404e8fa8440d826854b0dd",
# "node_1": "Powers",
# "node_2": "Nobility",
# "edge": "Dumbledore's refrain from using his powers is attributed to his noble character."
# }, {
# "chunk_id": "17c96105c1404e8fa8440d826854b0dd",
# "node_1": "Professor McGonagall",
# "node_2": "Anxious",
# "edge": "Professor McGonagall is presented as being anxious to discuss a certain topic."
# }, {
# "chunk_id": "17c96105c1404e8fa8440d826854b0dd",
# "node_1": "Professor McGonagall",
# "node_2": "Rumors",
# "edge": "Professor McGonagall is the source of rumors about Voldemort's disappearance and final defeat."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
# "chunk_id": "26c5b0d9c07d41e7baccd8e596c93446",
# "node_1": "Dumbledore",
# "node_2": "a piercing stare",
# "edge": "Dumbledore is receiving a piercing stare from Hermione"
# },
# {
# "chunk_id": "26c5b0d9c07d41e7baccd8e596c93446",
# "node_1": "Hermione",
# "node_2": "a piercing stare",
# "edge": "Hermione is directing a piercing stare towards Dumbledore"
# },
# {
# "chunk_id": "26c5b0d9c07d41e7baccd8e596c93446",
# "node_1": "Hermione",
# "node_2": "not believe the rumor",
# "edge": "Hermione refuses to believe the rumor about the Potters until Dumbledore confirms it"
# },
# {
# "chunk_id": "26c5b0d9c07d41e7baccd8e596c93446",
# "node_1": "Voldemort",
# "node_2": "turn up in Godric's Hollow",
# "edge": "Voldemort appeared in Godric's Hollow last night"
# },
# {
# "chunk_id": "26c5b0d9c07d41e7baccd8e596c93446",
# "node_1": "Voldemort",
# "node_2": "go to find the Potters",
# "edge": "Voldemort visited the Potters' residence"
# },
# {
# "chunk_id": "26c5b0d9c07d41e7baccd8e596c93446",
# "node_1": "Lily and James Potter",
# "node_2": "are dead",
# "edge": "the rumor suggests that Lily and James Potter have passed away"
# },
# {
# "chunk_id": "26c5b0d9c07d41e7baccd8e596c93446",
# "node_1": "Voldemort",
# "node_2": "try to kill the Potter's son, Harry",
# "edge": "Voldemort made an attempt on Harry Potter's life"
# },
# {
# "chunk_id": "26c5b0d9c07d41e7baccd8e596c93446",
# "node_1": "Voldemort",
# "node_2": "could not kill Harry Potter",
# "edge": "Harry Potter survived Voldemort's attack"
# },
# {
# "chunk_id": "26c5b0d9c07d41e7baccd8e596c93446",
# "node_1": "the reason behind Harry's survival",
# "node_2": "unknown",
# "edge": "nobody is aware of the cause behind Harry's survival"
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "a098a6a30133471ea74483e217f6742f",
# "node_1": "Voldemort's power",
# "node_2": "killing Harry Potter",
# "edge": "Voldemort's power somehow broke when he couldn't kill Harry Potter"
# },
# {
# "chunk_id": "a098a6a30133471ea74483e217f6742f",
# "node_1": "Voldemort",
# "node_2": "killing a little boy (Harry Potter)",
# "edge": "Voldemort couldn't kill Harry Potter, despite his ability to kill many people in the past"
# },
# {
# "chunk_id": "a098a6a30133471ea74483e217f6742f",
# "node_1": "Harry Potter",
# "node_2": "surviving an attack from Voldemort",
# "edge": "Harry survived an attack from Voldemort, which led to Voldemort's power breaking"
# },
# {
# "chunk_id": "a098a6a30133471ea74483e217f6742f",
# "node_1": "Hagrid",
# "node_2": "being late and informing about Dumbledore's whereabouts",
# "edge": "Hagrid is late and informed the recipient that Dumbledore would be there"
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "5f82479908824d8b840c6a2bedd670c1",
#        "node_1": "Hagrid",
#        "node_2": "being late",
#        "edge": "Hagrid is the one who is late"
#    },
#    {
#        "chunk_id": "5f82479908824d8b840c6a2bedd670c1",
#        "node_1": "Hagrid",
#        "node_2": "telling about Harry's whereabouts",
#        "edge": "Hagrid is the one who told Professor McGonagall that Harry would be there"
#    },
#    {
#        "chunk_id": "5f82479908824d8b840c6a2bedd670c1",
#        "node_1": "Professor McGonagall",
#        "node_2": "watching the Dursleys",
#        "edge": "Professor McGonagall has been watching the Dursleys all day"
#    },
#    {
#        "chunk_id": "5f82479908824d8b840c6a2bedd670c1",
#        "node_1": "Dursleys",
#        "node_2": "being Harry's only family left",
#        "edge": "The Dursleys are the only family that Harry has left now"
#    },
#    {
#        "chunk_id": "5f82479908824d8b840c6a2bedd670c1",
#        "node_1": "Dursleys",
#        "node_2": "not being like Hogwarts' people",
#        "edge": "Professor McGonagall pointed out that the Dursleys are less like Hogwarts' people"
#    },
#    {
#        "chunk_id": "5f82479908824d8b840c6a2bedd670c1",
#        "node_1": "Dursleys' son",
#        "node_2": "mistreating his mother",
#        "edge": "Professor McGonagall saw the Dursleys' son kicking his mother all the way up the street"
#    },
#    {
#        "chunk_id": "5f82479908824d8b840c6a2bedd670c1",
#        "node_1": "Harry Potter",
#        "node_2": "living with the Dursleys",
#        "edge": "Dumbledore thinks that it's the best place for Harry to live"
#    },
#    {
#        "chunk_id": "5f82479908824d8b840c6a2bedd670c1",
#        "node_1": "Harry's aunt and uncle",
#        "node_2": "explaining everything to Harry when he's older",
#        "edge": "Dumbledore thinks that Harry's aunt and uncle will be able to explain everything to him when he's older"
#    },
#    {
#        "chunk_id": "5f82479908824d8b840c6a2bedd670c1",
#        "node_1": "Dumbledore",
#        "node_2": "writing a letter to the Dursleys",
#        "edge": "Dumbledore has written a letter to the Dursleys"
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
# "chunk_id": "bdb2e4839663467b9aa11e054ef7dd3c",
# "node_1": "Harry Potter",
# "node_2": "legend",
# "edge": "Harry Potter will become a legend in the future, as predicted by Ron."
# },
# {
# "chunk_id": "bdb2e4839663467b9aa11e054ef7dd3c",
# "node_1": "Harry Potter",
# "node_2": "famous person",
# "edge": "Harry Potter is predicted to be a famous person in the future, as mentioned by Ron."
# },
# {
# "chunk_id": "bdb2e4839663467b9aa11e054ef7dd3c",
# "node_1": "Harry Potter day",
# "node_2": "future event",
# "edge": "Harry Potter day is predicted to be a future event, according to Ron."
# },
# {
# "chunk_id": "bdb2e4839663467b9aa11e054ef7dd3c",
# "node_1": "books",
# "node_2": "Harry Potter related",
# "edge": "There will be books written about Harry Potter in the future, as stated by Ron."
# },
# {
# "chunk_id": "bdb2e4839663467b9aa11e054ef7dd3c",
# "node_1": "every child in our world",
# "node_2": "Harry Potter knowledgeable group",
# "edge": "Every child in our world will know Harry Potter's name, as mentioned by Ron."
# },
# {
# "chunk_id": "bdb2e4839663467b9aa11e054ef7dd3c",
# "node_1": "Harry",
# "node_2": "unable to remember the event",
# "edge": "Harry will not remember the event, as pointed out by Dumbledore."
# },
# {
# "chunk_id": "bdb2e4839663467b9aa11e054ef7dd3c",
# "node_1": "growing up away from fame",
# "node_2": "better option for Harry",
# "edge": "Dumbledore believes that growing up away from fame is a better option for Harry."
# },
# {
# "chunk_id": "bdb2e4839663467b9aa11e054ef7dd3c",
# "node_1": "Hagrid",
# "node_2": "trusted with bringing Harry",
# "edge": "Dumbledore trusts Hagrid with bringing Harry."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
# "chunk_id": "c36613de4895487183a1548ecd92079e",
# "node_1": "Hagrid",
# "node_2": "trust",
# "edge": "Hagrid is an individual who is trusted by Dumbledore with something important."
# },
# {
# "chunk_id": "c36613de4895487183a1548ecd92079e",
# "node_1": "Hagrid",
# "node_2": "motorcycle",
# "edge": "Hagrid is associated with a huge motorcycle."
# },
# {
# "chunk_id": "c36613de4895487183a1548ecd92079e",
# "node_1": "motorcycle",
# "node_2": "falling from sky",
# "edge": "The motorcycle falls from the sky."
# },
# {
# "chunk_id": "c36613de4895487183a1548ecd92079e",
# "node_1": "man on motorcycle",
# "node_2": "extreme size",
# "edge": "The man sitting on the motorcycle is extremely large in size."
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#  {
# "chunk_id": "88ed240dd542497c973d6ff539661096",
# "node_1": "Hagrid",
# "node_2": "Motorcycle",
# "edge": "Hagrid got the motorcycle from Sirius Black"
# },
# {
# "chunk_id": "88ed240dd542497c973d6ff539661096",
# "node_1": "Motorcycle",
# "node_2": "Sirius Black",
# "edge": "The motorcycle belongs to Sirius Black"
# },
# {
# "chunk_id": "88ed240dd542497c973d6ff539661096",
# "node_1": "Hagrid",
# "node_2": "Baby boy (Harry)",
# "edge": "Hagrid saved the baby boy and is now holding him"
# },
# {
# "chunk_id": "88ed240dd542497c973d6ff539661096",
# "node_1": "Baby boy (Harry)",
# "node_2": "Curiously shaped cut on the forehead",
# "edge": "The baby boy has a cut that looks like a bolt of lightning"
# },
# {
# "chunk_id": "88ed240dd542497c973d6ff539661096",
# "node_1": "Curiously shaped cut on the forehead",
# "node_2": "Dumbledore",
# "edge": "Dumbledore confirms that the baby boy will have the scar forever"
# },
# {
# "chunk_id": "88ed240dd542497c973d6ff539661096",
# "node_1": "Professor McGonagall",
# "node_2": "Curiously shaped cut on the forehead",
# "edge": "Professor McGonagall wonders if that's where the scar is"
# }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "e166e7938f74495db1014b34b5a82ca8",
#        "node_1": "Dumbledore",
#        "node_2": "power to remove scars",
#        "edge": "Dumbledore has the power to remove scars, but he chooses not to do so for Harry's benefit"
#    },
#    {
#        "chunk_id": "e166e7938f74495db1014b34b5a82ca8",
#        "node_1": "Scars",
#        "node_2": "usefulness",
#        "edge": "Scars can be useful, as demonstrated by Dumbledore's scar that acts as a map of the London Underground"
#    },
#    {
#        "chunk_id": "e166e7938f74495db1014b34b5a82ca8",
#        "node_1": "Hagrid",
#        "node_2": "emotional state",
#        "edge": "Hagrid is emotionally affected by the death of Lily and James and Harry's upbringing with Muggles"
#    },
#    {
#        "chunk_id": "e166e7938f74495db1014b34b5a82ca8",
#        "node_1": "Professor McGonagall",
#        "node_2": "concern for waking Muggles",
#        "edge": "Professor McGonagall is concerned about waking the Dursleys, who are Muggles"
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "4c47529bd66d4ccaa40e6044ba2fc452",
#        "node_1": "Hagrid",
#        "node_2": "motorcycle",
#        "edge": "Hagrid swung himself onto the motorcycle and kicked the engine into life"
#    },
#    {
#        "chunk_id": "4c47529bd66d4ccaa40e6044ba2fc452",
#        "node_1": "Hagrid",
#        "node_2": "Dumbledore",
#        "edge": "Hagrid and Dumbledore were standing near the door looking at Harry's bundle"
#    },
#    {
#        "chunk_id": "4c47529bd66d4ccaa40e6044ba2fc452",
#        "node_1": "Hagrid",
#        "node_2": "Professor McGonagall",
#        "edge": "Hagrid, Professor McGonagall and Dumbledore were looking at Harry's bundle"
#    },
#    {
#        "chunk_id": "4c47529bd66d4ccaa40e6044ba2fc452",
#        "node_1": "Hagrid",
#        "node_2": "Professor McGonagall",
#        "edge": "Professor McGonagall patted Hagrid gingerly on the arm"
#    },
#    {
#        "chunk_id": "4c47529bd66d4ccaa40e6044ba2fc452",
#        "node_1": "Hagrid",
#        "node_2": "Sirius",
#        "edge": "Hagrid was taking Sirius his bike back"
#    },
#    {
#        "chunk_id": "4c47529bd66d4ccaa40e6044ba2fc452",
#        "node_1": "Dumbledore",
#        "node_2": "Harry's blanket",
#        "edge": "Dumbledore tucked a letter inside Harry's blankets"
#    },
#    {
#        "chunk_id": "4c47529bd66d4ccaa40e6044ba2fc452",
#        "node_1": "Dumbledore",
#        "node_2": "Professor McGonagall",
#        "edge": "Dumbledore, Professor McGonagall and Hagrid were standing near Harry's bundle"
#    },
#    {
#        "chunk_id": "4c47529bd66d4ccaa40e6044ba2fc452",
#        "node_1": "Harry's bundle",
#        "node_2": "doorstep",
#        "edge": "Harry was lying on the doorstep"
#    },
#    {
#        "chunk_id": "4c47529bd66d4ccaa40e6044ba2fc452",
#        "node_1": "Dumbledore",
#        "node_2": "celebrations",
#        "edge": "Dumbledore suggested to join the celebrations"
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
# "chunk_id": "344f0b8a18274f7e8a3
#
#
# ERROR ### Here is the buggy response:  {'model': 'mixtral:latest', 'created_at': '2024-05-14T15:57:02.722419Z', 'response': ' [\n{\n"chunk_id": "344f0b8a18274f7e8a3', 'done': True, 'done_reason': 'stop', 'context': [28705, 733, 16289, 28793, 995, 460, 264, 3681, 5246, 27065, 693, 9131, 28713, 3471, 304, 652, 3136, 477, 264, 2078, 2758, 28723, 995, 460, 3857, 395, 264, 2758, 11077, 325, 5149, 321, 1345, 486, 8789, 28731, 3604, 3638, 349, 298, 9131, 272, 7957, 2161, 302, 3471, 7083, 297, 272, 2078, 2758, 28723, 2957, 3471, 1023, 2904, 272, 1945, 16582, 390, 660, 272, 2758, 28723, 28705, 13, 1227, 1322, 28705, 28740, 28747, 4023, 19483, 288, 1059, 1430, 12271, 28725, 15403, 684, 272, 1945, 3471, 7083, 297, 378, 28723, 13, 12, 11579, 28713, 993, 3024, 1338, 325, 14702, 557, 4723, 28725, 6666, 28725, 3608, 28725, 11964, 28725, 28705, 13, 12, 12058, 28725, 5935, 28725, 1928, 28725, 9040, 28705, 4345, 28723, 13, 12, 11579, 28713, 1023, 347, 390, 18040, 3320, 390, 2572, 13, 13, 1227, 1322, 28705, 28750, 28747, 15403, 684, 910, 1167, 3471, 541, 506, 624, 356, 624, 9378, 395, 799, 3471, 28723, 13, 12, 11579, 28713, 369, 460, 7083, 297, 272, 1348, 12271, 442, 272, 1348, 18438, 460, 9566, 5202, 298, 1430, 799, 28723, 13, 12, 11579, 28713, 541, 347, 5202, 298, 1287, 799, 3471, 13, 13, 1227, 1322, 28705, 28770, 28747, 8769, 575, 272, 9378, 1444, 1430, 1259, 5202, 5964, 302, 3471, 28723, 28705, 13, 13, 5056, 574, 3825, 390, 264, 1274, 302, 7611, 28723, 7066, 2442, 302, 272, 1274, 5876, 264, 5964, 302, 3471, 391, 272, 9378, 1444, 706, 737, 272, 285, 793, 9988, 28723, 9991, 3491, 2268, 272, 1192, 302, 272, 11077, 28730, 1138, 390, 4057, 297, 456, 11510, 28747, 28705, 13, 28792, 13, 259, 371, 13, 428, 345, 13567, 28730, 313, 1264, 345, 28770, 28781, 28781, 28722, 28734, 28726, 28783, 28708, 28740, 28783, 28750, 28787, 28781, 28722, 28787, 28706, 28783, 28708, 28770, 28783, 28783, 28787, 28781, 28717, 28783, 28782, 1705, 28740, 28783, 2684, 548, 13, 428, 345, 2315, 28730, 28740, 1264, 345, 28741, 5935, 477, 25081, 7957, 2161, 548, 13, 428, 345, 2315, 28730, 28750, 1264, 345, 28741, 5202, 5935, 477, 25081, 7957, 2161, 548, 13, 428, 345, 8424, 1264, 345, 3045, 18798, 1444, 272, 989, 16582, 28725, 3179, 28730, 28740, 304, 3179, 28730, 28750, 297, 624, 442, 989, 23748, 28739, 13, 259, 1630, 371, 1101, 28752, 13, 28793, 2758, 28747, 8789, 28713, 12553, 333, 28725, 382, 357, 3361, 21701, 2722, 5380, 272, 8609, 15660, 304, 17444, 272, 4456, 778, 1411, 28745, 395, 264, 712, 283, 378, 8536, 778, 272, 2423, 304, 805, 778, 272, 2125, 28723, 345, 28737, 4579, 1032, 368, 3403, 28725, 315, 1675, 28725, 11962, 18407, 266, 357, 455, 862, 773, 384, 12802, 431, 28725, 5460, 3202, 298, 559, 28723, 11962, 18407, 266, 357, 455, 21798, 559, 9948, 297, 10071, 28723, 384, 12802, 431, 2897, 304, 5610, 852, 1060, 272, 5948, 28723, 1418, 272, 6581, 400, 5426, 304, 2056, 575, 272, 9746, 10331, 28733, 2919, 263, 28723, 650, 26399, 378, 2327, 28725, 304, 13153, 16852, 302, 2061, 668, 286, 852, 298, 652, 5948, 305, 10991, 579, 369, 15650, 299, 16857, 1272, 10552, 6914, 14545, 304, 400, 829, 1038, 575, 264, 7683, 1403, 5255, 1135, 10593, 1401, 272, 6581, 438, 272, 799, 948, 302, 272, 5948, 28723, 650, 829, 776, 1032, 272, 15484, 302, 9522, 1468, 356, 272, 3707, 302, 1474, 2308, 28723, 345, 10604, 6576, 28725, 9726, 862, 400, 24683, 28723, 650, 2897, 356, 516, 400, 301, 304, 395, 264, 1719, 789, 302, 516, 23390, 491, 28725, 400, 403, 4214, 28723, 28705, 330, 24284, 408, 26545, 272, 17730, 23737, 2711, 302, 15650, 299, 16857, 28725, 690, 4897, 10832, 304, 12158, 28724, 916, 272, 297, 4845, 7212, 28725, 272, 1215, 1432, 1633, 368, 682, 1675, 21011, 5596, 1722, 298, 4804, 28723, 9726, 10650, 360, 12183, 754, 3416, 516, 9522, 1468, 1671, 275, 1288, 582, 28723, 2387, 13940, 28832, 28705, 13, 13, 3825, 28747, 28705, 733, 28748, 16289, 28793, 733, 13, 28751, 13, 28739, 13567, 28730, 313, 1264, 345, 28770, 28781, 28781, 28722, 28734, 28726, 28783, 28708, 28740, 28783, 28750, 28787, 287 ...
#
#
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "ddf9749327e34206a38ea0f8b56be1f5",
#        "node_1": "Harry Potter",
#        "node_2": "Astonishing things",
#        "edge": "Harry Potter is associated with astonishing things as he is the subject of those astonishing things"
#    },
#    {
#        "chunk_id": "ddf9749327e34206a38ea0f8b56be1f5",
#        "node_1": "Harry Potter",
#        "node_2": "Special",
#        "edge": "Harry Potter is considered special by people who are holding up their glasses and saying in hushed voices: 'To Harry Potter -- the boy who lived!'"
#    },
#    {
#        "chunk_id": "ddf9749327e34206a38ea0f8b56be1f5",
#        "node_1": "Harry Potter",
#        "node_2": "Famous",
#        "edge": "Harry Potter is famous as people are holding up their glasses and saying in hushed voices: 'To Harry Potter -- the boy who lived!'"
#    },
#    {
#        "chunk_id": "ddf9749327e34206a38ea0f8b56be1f5",
#        "node_1": "Harry Potter",
#        "node_2": "Woken up",
#        "edge": "Harry Potter will be woken up in a few hours' time by Mrs. Dursley's scream as she opens the front door to put out the milk bottles"
#    },
#    {
#        "chunk_id": "ddf9749327e34206a38ea0f8b56be1f5",
#        "node_1": "Harry Potter",
#        "node_2": "Prodded and pinched",
#        "edge": "Harry Potter will be prodded and pinched by his cousin Dudley in the next few weeks"
#    },
#    {
#        "chunk_id": "ddf9749327e34206a38ea0f8b56be1f5",
#        "node_1": "People meeting in secret",
#        "node_2": "Harry Potter",
#        "edge": "People are holding up their glasses and saying in hushed voices: 'To Harry Potter -- the boy who lived!'"
#    }
# ]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# (173, 5)
#                            chunk_id        node_1  \
# 0  55fba9390d9b40a9b2080b407539097c   mr. dursley
# 1  55fba9390d9b40a9b2080b407539097c        dudley
# 2  55fba9390d9b40a9b2080b407539097c  the dursleys
# 3  55fba9390d9b40a9b2080b407539097c  the dursleys
# 4  48e4a5ce2c81495db5523f7dcbc077d6   mr. dursley
#
#                             node_2  \
# 0                        grunnings
# 1                     the dursleys
# 2                           secret
# 3             mrs. potter's family
# 4  mrs. dursley's sister's husband
#
#                                                 edge  count
# 0  Mr. Dursley is the director of Grunnings, a fi...      4
# 1           Dudley is the small son of the Dursleys.      4
# 2  The Dursleys have a secret, and their greatest...      4
# 3  The Dursleys' greatest fear is that someone wo...      4
# 4  Mr. Dursley considers Mrs. Dursley's sister's ...      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
dfg2 = contextual_proximity(dfg1)
dfg2.to_csv(output_context_prox_file_with_path, sep=";", index=False)
dfg2.tail()
# Out:
#                                 node_1                node_2  \
# 2221  writing a letter to the dursleys                hagrid
# 2231                      you-know-who            dumbledore
# 2233                      you-know-who                powers
# 2234                      you-know-who  professor mcgonagall
# 2236                      you-know-who             voldemort
#
#                                                chunk_id  count  \
# 2221  5f82479908824d8b840c6a2bedd670c1,5f82479908824...      2
# 2231  17c96105c1404e8fa8440d826854b0dd,17c96105c1404...      2
# 2233  17c96105c1404e8fa8440d826854b0dd,17c96105c1404...      2
# 2234  17c96105c1404e8fa8440d826854b0dd,17c96105c1404...      2
# 2236  17c96105c1404e8fa8440d826854b0dd,17c96105c1404...      2
#
#                       edge
# 2221  contextual proximity
# 2231  contextual proximity
# 2233  contextual proximity
# 2234  contextual proximity
# 2236  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                node_1                node_2  \
# 0            'potter'           mr. dursley
# 1            'potter'          mrs. dursley
# 2            'potter'               petunia
# 3            'potter'     sister of petunia
# 4    a piercing stare              are dead
# ..                ...                   ...
# 789      you-know-who            dumbledore
# 790      you-know-who                powers
# 791      you-know-who  professor mcgonagall
# 792      you-know-who             voldemort
# 793       youknow-who             voldemort
#
#                                               chunk_id  \
# 0    5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...
# 1    5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...
# 2    5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...
# 3    5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...
# 4    26c5b0d9c07d41e7baccd8e596c93446,26c5b0d9c07d4...
# ..                                                 ...
# 789  17c96105c1404e8fa8440d826854b0dd,17c96105c1404...
# 790  17c96105c1404e8fa8440d826854b0dd,17c96105c1404...
# 791  17c96105c1404e8fa8440d826854b0dd,17c96105c1404...
# 792  17c96105c1404e8fa8440d826854b0dd,17c96105c1404...
# 793                   0a172c4d70d34552bb20440b65f72350
#
#                                                   edge  count
# 0                                 contextual proximity      2
# 1                                 contextual proximity      2
# 2                                 contextual proximity      2
# 3    The name 'Potter' is related to Petunia's sist...      7
# 4                                 contextual proximity      2
# ..                                                 ...    ...
# 789                               contextual proximity      2
# 790                               contextual proximity      2
# 791                               contextual proximity      2
# 792  You-Know-Who is a nickname or alias for the ac...      6
# 793  In this context, they refer to the same person...      4
#
# [794 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (192,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  12
# [["'potter'", 'bakery', 'car', 'cat', 'collecting tin', "daughter's problems", 'driving', 'dudley', "dudley's age", 'fear', 'five different people', 'frozen in armchair', 'grunnings', 'grunnings parking lot', 'half past eight', 'happy', 'harry', 'he', "heard the name 'potter'", 'howard/harry', 'learning new word', 'lily potter (implied)', 'looking at the sign', 'lunchtime', 'map', 'morning', 'mr. dursley', "mr. dursley's garden wall", 'mrs. dursley', "mrs. dursley's sister's husband", 'mrs. next door', "mrs. potter's family", 'muggle', 'nasty, common name', "nation's owls", 'night hunting', 'normal behavior', 'normal day', 'not young', 'noticing strange people', 'owl-free', 'owls', 'people down in the street', 'people in cloaks', 'petunia', 'potters', 'secret', 'several important telephone calls', 'sister of petunia', 'son, harry', 'strangely dressed people', 'stranger', 'tabby cat', 'the dursleys', 'the potters', "the potters' son", "the potters, that's right, that's what i heard yes, their son, harry", 'their son', 'thinking of large order of drills', 'unable to remember the event', 'unusual behavior', 'violet cloak', 'whispering excitedly', 'whispering excitedly together'], ['a kind of muggle sweet', 'lemon drops'], ['a piercing stare', 'amusement', 'anxious', 'are dead', 'astonishing things', 'baby boy (harry)', "being harry's only family left", 'being late', "being late and informing about dumbledore's whereabouts", 'better option for harry', 'black hair in a tight bun', 'books', 'celebrations', 'concern for waking muggles', 'could not kill harry potter', 'curiously shaped cut on the forehead', 'darkness', 'doorstep', 'dumbledore', 'dursleys', "dursleys' son", 'emerald cloak', 'emotional state', 'every child in our world', "explaining everything to harry when he's older", 'extreme size', 'falling from sky', 'famous', 'famous person', 'future event', 'go to find the potters', 'growing up away from fame', 'hagrid', 'harry potter', 'harry potter day', 'harry potter knowledgeable group', 'harry potter related', "harry's aunt and uncle", "harry's blanket", "harry's bundle", 'hermione', 'killing a little boy (harry potter)', 'legend', 'lily and james potter', 'living with the dursleys', 'man on motorcycle', 'mistreating his mother', 'motorcycle', 'nobility', "not being like hogwarts' people", 'not believe the rumor', 'number of feasts and parties on her way here', 'people meeting in secret', 'power to remove scars', 'powers', 'prodded and pinched', 'professor mcgonagall', 'put-outer', 'ruffled appearance', 'rumors', 'severe-looking woman', 'silver cigarette lighter', 'sirius', 'sirius black', 'special', 'square glasses', 'street lamps', 'surviving an attack from voldemort', "telling about harry's whereabouts", "the reason behind harry's survival", 'trust', 'trusted with bringing harry', "try to kill the potter's son, harry", "turn up in godric's hollow", 'unknown', 'voldemort', 'watching the dursleys', 'woken up', 'writing a letter to the dursleys', 'you-know-who', 'youknow-who'], ['albus dumbledore', 'blue eyes, light, bright and sparkling behind half-moon spectacles', 'boss', 'corner', 'home number', 'long and crooked nose', 'long robes, purple cloak and high-heeled boots', 'looking up suddenly at the cat', 'man', 'nephew', 'not realizing he had just arrived in a street where everything from his name to his boots was unwelcome', 'office', 'privet drive', 'realizing he was being watched', 'rummaging in his cloak, looking for something', 'secretary', 'silver hair and beard', 'tall, thin and very old', 'tiny old man'], ['are being downright careless, out on the streets in broad daylight, not even dressed in muggle clothes, swapping rumors', 'dedalus diggle', 'disappearance of youknow-who', 'flocks of owls, shooting stars', "have noticed something's going on", 'muggles', 'muggles have noticed', 'non-magical people', 'not completely stupid', 'people', 'people are careless, spreading rumors', 'unusual events'], ['downpour of shooti ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                                   node    color  group
# 0                                             'potter'  #d3db57      1
# 1                                               bakery  #d3db57      1
# 2                                                  car  #d3db57      1
# 3                                                  cat  #d3db57      1
# 4                                       collecting tin  #d3db57      1
# ..                                                 ...      ...    ...
# 187                                         weatherman  #a157db     10
# 188                                              scars  #db5f57     11
# 189                                         usefulness  #db5f57     11
# 190  strange and mysterious things happening all ov...  #5791db     12
# 191                                        the weather  #5791db     12
#
# [192 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

#graph_output_directory = "./docs/index.html"

net = Network(
    notebook=True,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="800px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)

# net.show(graph_output_directory)
net.show_buttons(filter_=['physics'])
net.show("knowledge_graph.html")
# Out:
# knowledge_graph.html
#         <iframe
#             width="100%"
#             height="800px"
#             src="knowledge_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# DETAILED STEPS OF TERM PROXIMITY CALCULATION (same as function, only step by step to better understand the process)

# %%
## Melt the dataframe into a list of nodes
dfg_long = pd.melt(
    dfg1, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
)

# %%
dfg_long.tail(5)
# Out:
#                              chunk_id variable                 node
# 341  ddf9749327e34206a38ea0f8b56be1f5   node_2              special
# 342  ddf9749327e34206a38ea0f8b56be1f5   node_2               famous
# 343  ddf9749327e34206a38ea0f8b56be1f5   node_2             woken up
# 344  ddf9749327e34206a38ea0f8b56be1f5   node_2  prodded and pinched
# 345  ddf9749327e34206a38ea0f8b56be1f5   node_2         harry potter

# %%
dfg_long.drop(columns=["variable"], inplace=True)
# Self join with chunk id as the key will create a link between terms occuring in the same text chunk.

# %%
dfg_long.tail(5)
# Out:
#                              chunk_id                 node
# 341  ddf9749327e34206a38ea0f8b56be1f5              special
# 342  ddf9749327e34206a38ea0f8b56be1f5               famous
# 343  ddf9749327e34206a38ea0f8b56be1f5             woken up
# 344  ddf9749327e34206a38ea0f8b56be1f5  prodded and pinched
# 345  ddf9749327e34206a38ea0f8b56be1f5         harry potter

# %%
dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))

# %%
dfg_wide.head()
# Out:
#                            chunk_id       node_1        node_2
# 0  55fba9390d9b40a9b2080b407539097c  mr. dursley   mr. dursley
# 1  55fba9390d9b40a9b2080b407539097c  mr. dursley        dudley
# 2  55fba9390d9b40a9b2080b407539097c  mr. dursley  the dursleys
# 3  55fba9390d9b40a9b2080b407539097c  mr. dursley  the dursleys
# 4  55fba9390d9b40a9b2080b407539097c  mr. dursley     grunnings

# %%
# drop self loops
self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
dfgraph2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)

# %%
dfgraph2.head()
# Out:
#                            chunk_id       node_1        node_2
# 0  55fba9390d9b40a9b2080b407539097c  mr. dursley        dudley
# 1  55fba9390d9b40a9b2080b407539097c  mr. dursley  the dursleys
# 2  55fba9390d9b40a9b2080b407539097c  mr. dursley  the dursleys
# 3  55fba9390d9b40a9b2080b407539097c  mr. dursley     grunnings
# 4  55fba9390d9b40a9b2080b407539097c  mr. dursley  the dursleys

# %%
## Group and count edges.
dfgraph2 = (
    dfgraph2.groupby(["node_1", "node_2"])
    .agg({"chunk_id": [",".join, "count"]})
    .reset_index()
)

# %%
dfgraph2.head()
# Out:
#      node_1                   node_2  \
#
# 0  'potter'  heard the name 'potter'
# 1  'potter'    lily potter (implied)
# 2  'potter'              mr. dursley
# 3  'potter'             mrs. dursley
# 4  'potter'                  petunia
#
#                                             chunk_id
#                                                 join count
# 0                   5e6a39886ae44e48ade45448fc9051ca     1
# 1                   5e6a39886ae44e48ade45448fc9051ca     1
# 2  5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...     2
# 3  5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...     2
# 4  5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...     2

# %%
dfgraph2.columns = ["node_1", "node_2", "chunk_id", "count"]
dfgraph2.replace("", np.nan, inplace=True)
dfgraph2.dropna(subset=["node_1", "node_2"], inplace=True)
# Drop edges with 1 count
dfgraph2 = dfg2[dfg2["count"] != 1]
dfgraph2["edge"] = "contextual proximity"

# %%
dfgraph2.head()
# Out:
#               node_1             node_2  \
# 2           'potter'        mr. dursley
# 3           'potter'       mrs. dursley
# 4           'potter'            petunia
# 5           'potter'  sister of petunia
# 11  a piercing stare           are dead
#
#                                              chunk_id  count  \
# 2   5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...      2
# 3   5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...      2
# 4   5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...      2
# 5   5e6a39886ae44e48ade45448fc9051ca,5e6a39886ae44...      3
# 11  26c5b0d9c07d41e7baccd8e596c93446,26c5b0d9c07d4...      2
#
#                     edge
# 2   contextual proximity
# 3   contextual proximity
# 4   contextual proximity
# 5   contextual proximity
# 11  contextual proximity

# %%
dfgraph2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 748 entries, 2 to 2236
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   node_1    748 non-null    object
#  1   node_2    748 non-null    object
#  2   chunk_id  748 non-null    object
#  3   count     748 non-null    int64
#  4   edge      748 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 35.1+ KB
